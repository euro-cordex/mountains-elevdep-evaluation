# %% [markdown]
# # regions of interest

# %%
# import cartopy.crs as ccrs
# import matplotlib.pyplot as plt
import numpy as np
import folium
from ipyleaflet import basemaps
import regionmask

# %pwd
# Out:
# '/home/mmatiu/projects/mountains-elevdep-evaluation/notebooks'

# %% [markdown]
# ## define regions

# %%
alps = np.array([[4.5, 43], [4.5, 48.5], [17, 48.5], [17, 43]])

carpathians = np.array([[17.0, 44], [17, 50.5], [27.5, 50.5], [27.5, 44]]) # 4 corners
# carpathians = np.array([[21.0, 47], [17.0, 47], [17, 50.5], [27.5, 50.5], [27.5, 44], [21.0, 44]])

pyrenees = np.array([[-2.5, 41.6], [-2.5, 43.6], [3.5, 43.6], [3.5, 41.6]])

scandes = np.array([[-1.0, 57.5], [17, 71.5], [33, 71.5], [15, 57.5]]) # 4 corners
# scandes = np.array([[3.0, 57.5], [3.0, 62], [18, 71.5], [33, 71.5], [15, 57.5]])

# %%
names = ["Alps", "Carpathians", "Pyrenees", "Scandes"]
abbrevs = ["Alp", "Car", "Pyr", "Sca"]

regions = regionmask.Regions([alps, carpathians, pyrenees, scandes], names=names, abbrevs=abbrevs, name="Mountain Regions")

# %%
# simple plot
# regions.plot(label="abbrev")

# %%
# prep and save
regions_gdf = regions.to_geodataframe().set_crs(epsg=4326)

regions_gdf.to_file("../data/regions.gpkg")

# %% [markdown]
# ## view on map

# %%
m = folium.Map([50, 7], zoom_start=3, tiles=basemaps.OpenTopoMap)
folium.GeoJson(regions_gdf).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_902ac8406e8b783ce41d0e97c927d2c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_902ac8406e8b783ce41d0e97c927d2c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_902ac8406e8b783ce41d0e97c927d2c4 = L.map(
#                 &quot;map_902ac8406e8b783ce41d0e97c927d2c4&quot;,
#                 {
#                     center: [50.0, 7.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ee3a3553ec91e916127a6fcda52605d7 = L.tileLayer(
#                 &quot;https://{s}.tile.opentopomap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 17,
#   &quot;maxNativeZoom&quot;: 17,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map data: \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors, \u003ca href=\&quot;http://viewfinderpanoramas.org\&quot;\u003eSRTM\u003c/a\u003e | Map style: \u0026copy; \u003ca href=\&quot;https://opentopomap.org\&quot;\u003eOpenTopoMap\u003c/a\u003e (\u003ca href=\&quot;https://creativecommons.org/licenses/by-sa/3.0/\&quot;\u003eCC-BY-SA\u003c/a\u003e)&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ee3a3553ec91e916127a6fcda52605d7.addTo(map_902ac8406e8b783ce41d0e97c927d2c4);
#
#
#
#         function geo_json_8bb21b04a7e5574adee4053cd65e784d_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_8bb21b04a7e5574adee4053cd65e784d = L.geoJson(null, {
#                 onEachFeature: geo_json_8bb21b04a7e5574adee4053cd65e784d_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_8bb21b04a7e5574adee4053cd65e784d_add (data) {
#             geo_json_8bb21b04a7e5574adee4053cd65e784d
#                 .addData(data);
#         }
#             geo_json_8bb21b04a7e5574adee4053cd65e784d_add({&quot;bbox&quot;: [-2.5, 41.6, 33.0, 71.5], &quot;features&quot;: [{&quot;bbox&quot;: [4.5, 43.0, 17.0, 48.5], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[4.5, 43.0], [4.5, 48.5], [17.0, 48.5], [17.0, 43.0], [4.5, 43.0]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;abbrevs&quot;: &quot;Alp&quot;, &quot;names&quot;: &quot;Alps&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [17.0, 44.0, 27.5, 50.5], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[17.0, 44.0], [17.0, 50.5], [27.5, 50.5], [27.5, 44.0], [17.0, 44.0]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;abbrevs&quot;: &quot;Car&quot;, &quot;names&quot;: &quot;Carpathians&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-2.5, 41.6, 3.5, 43.6], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-2.5, 41.6], [-2.5, 43.6], [3.5, 43.6], [3.5, 41.6], [-2.5, 41.6]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;abbrevs&quot;: &quot;Pyr&quot;, &quot;names&quot;: &quot;Pyrenees&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-1.0, 57.5, 33.0, 71.5], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-1.0, 57.5], [17.0, 71.5], [33.0, 71.5], [15.0, 57.5], [-1.0, 57.5]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;abbrevs&quot;: &quot;Sca&quot;, &quot;names&quot;: &quot;Scandes&quot;}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#         geo_json_8bb21b04a7e5574adee4053cd65e784d.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_8bb21b04a7e5574adee4053cd65e784d.addTo(map_902ac8406e8b783ce41d0e97c927d2c4);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
